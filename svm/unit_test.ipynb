# %%
from data import SVMDataset
from torch.utils.data import DataLoader

# %%
dataset = SVMDataset(1000, 0.5)
dataloader = DataLoader(dataset, batch_size = 32, shuffle =True)
import torch
torch.set_default_tensor_type(torch.FloatTensor)
epochs = 10
for epoch in range(epochs):
    for iter, data in enumerate(dataloader):
        print(data[1].dtype)
# Out:
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64
# torch.int64

# %%
from svm import LinearSVM
model = LinearSVM()

# %%
X = torch.Tensor([[2,3],[4,5]])

print(model(X).t().shape)
print(model(X))
print(model(X).t())
print(model(X).t()*torch.Tensor([1,-1]))
# Out:
# torch.Size([1, 2])
# tensor([[0.9696],
#         [1.6718]], grad_fn=<AddmmBackward>)
# tensor([[0.9696, 1.6718]], grad_fn=<TBackward>)
# tensor([[ 0.9696, -1.6718]], grad_fn=<MulBackward0>)
